# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('placement.csv')
df.head(5)
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
# To remove the coloum of Unnamed (preprocessing)

df = df.iloc[:,1:]

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
# How to use EDA (Exploratory Data Analysis)

import matplotlib.pyplot as plt 

plt.scatter(df['cgpa'],df['iq'] , c = df['placement'])
plt.xlabel('cgpa')
plt.ylabel('iq')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x.shape
# Out:
# (100, 2)

# %%
type(x.shape)
# Out:
# tuple

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split 

X_train,X_test,Y_train,Y_test = train_test_split(x,y, test_size = 0.15)

# %%
X_train
# Out:
#     cgpa     iq
# 4    5.8  142.0
# 18   4.0  100.0
# 76   4.9  155.0
# 24   4.7  121.0
# 58   8.0   79.0
# ..   ...    ...
# 26   7.0  199.0
# 9    5.1   66.0
# 89   4.9  151.0
# 0    6.8  123.0
# 50   3.5  233.0
#
# [85 rows x 2 columns]

# %%
X_test.shape
# Out:
# (15, 2)

# %%
# how to scalering 

from sklearn.preprocessing import StandardScaler 

model = StandardScaler()

X_train = model.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.1165784 ,  0.40642264],
#        [-1.64106515, -0.66358386],
#        [-0.87882178,  0.73761513],
#        [-1.04820919, -0.12858061],
#        [ 1.74668319, -1.19858711],
#        [ 0.73035869, -0.91834732],
#        [-1.04820919, -1.88644843],
#        [-0.79412807, -0.20500965],
#        [ 0.47627756,  0.86499685],
#        [-1.30229032, -2.14121189],
#        [ 0.56097127,  0.30451726],
#        [-0.87882178, -1.65716133],
#        [ 0.47627756,  0.10070649],
#        [ 0.8997461 ,  0.3299936 ],
#        [ 0.64566498,  0.71213878],
#        [ 1.15382723, -1.0202527 ],
#        [-0.70943436,  1.27261838],
#        [ 0.8997461 , -0.35786772],
#        [-1.64106515, -1.30049249],
#        [ 0.05280902, -1.5297796 ],
#        [-0.96351548,  0.38094629],
#        [-0.62474065,  0.8904732 ],
#        [ 1.40790835,  0.0497538 ],
#        [ 0.73035869, -0.35786772],
#        [-1.1329029 ,  0.50832802],
#        [ 0.30689014,  0.0497538 ],
#        [ 0.98443981,  0.63570974],
#        [ 1.15382723, -1.93740113],
#        [ 1.8313769 ,  0.58475705],
#        [-0.20127211,  0.35546995],
#        [ 0.30689014, -0.58715483],
#        [ 0.05280902, -0.05215158],
#        [-0.96351548,  0.94142589],
#        [ 0.8150524 ,  0.3299936 ],
#        [ 0.05280902, -0.61263117],
#        [-0.62474065, -0.91834732],
#        [ 0.22219644, -0.33239137],
#        [ 0.56097127, -0.15405696],
#        [-0.62474065, -0.40882041],
#        [-0.1165784 ,  1.01785492],
#        [ 0.8150524 ,  0.30451726],
#        [-0.20127211,  1.09428396],
#        [ 0.8997461 , -1.58073229],
#        [-0.87882178, -0.15405696],
#        [ 1.32321465,  0.81404416],
#        [-0.70943436,  0.0497538 ],
#        [-0.79412807, -0.89287097],
#        [-0.62474065,  2.49548295],
#        [-0.03188469, -0.51072579],
#        [ 2.00076431,  1.06880761],
#        [-0.96351548, -0.35786772],
#        [-0.87882178,  0.20261188],
#        [ 1.32321465,  0.10070649],
#        [-1.72575886, -0.43429676],
#        [-1.38698403,  1.88405066],
#        [-1.30229032,  0.58475705],
#        [-0.62474065,  0.15165918],
#        [ 0.8150524 , -0.76548924],
#        [ 0.05280902, -2.06478285],
#        [-0.54004694, -0.12858061],
#        [-0.54004694, -0.30691503],
#        [ 0.39158385, -0.25596234],
#        [-0.96351548,  1.09428396],
#        [ 2.17015173, -0.15405696],
#        [ 1.8313769 ,  1.01785492],
#        [-0.45535323, -0.48524945],
#        [ 1.40790835, -0.94382366],
#        [ 0.13750273,  0.76309147],
#        [-0.45535323,  0.3299936 ],
#        [ 0.73035869,  0.38094629],
#        [ 0.30689014,  0.02427746],
#        [-0.20127211,  0.43189898],
#        [ 0.64566498,  1.42547645],
#        [-1.04820919, -0.99477635],
#        [-0.79412807, -1.60620864],
#        [ 0.8997461 ,  1.24714203],
#        [ 1.32321465, -1.65716133],
#        [ 1.15382723,  0.27904091],
#        [ 0.39158385,  0.38094629],
#        [-2.23392111,  1.45095279],
#        [ 0.8997461 ,  1.85857432],
#        [-0.70943436, -1.5297796 ],
#        [-0.87882178,  0.63570974],
#        [ 0.73035869, -0.07762792],
#        [-2.0645337 ,  2.72477005]])

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
X_test = model.fit_transform(X_test)

# %%
X_test
# Out:
# array([[-1.13032888,  0.64107084],
#        [-1.13032888,  0.11105164],
#        [ 1.40025816,  0.56535381],
#        [-0.24462341,  0.56535381],
#        [ 1.02067011, -1.55472298],
#        [-1.76297564,  2.18065041],
#        [ 1.90637557,  0.11105164],
#        [-0.24462341, -1.12565982],
#        [ 0.26149399, -1.83235208],
#        [ 1.27372881,  0.16152966],
#        [-0.24462341, -0.16657746],
#        [-0.37115277,  0.99441697],
#        [-0.24462341, -0.72183567],
#        [ 0.26149399, -0.49468458],
#        [-0.75074082,  0.56535381]])

# %%
# This is model Training 

from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
# Evaluate the model selection 

pred = model.predict(X_test)

# %%
Y_test
# Out:
# 49    0
# 41    0
# 3     1
# 71    1
# 5     1
# 80    0
# 55    1
# 56    0
# 82    1
# 72    1
# 14    0
# 33    0
# 78    0
# 79    1
# 87    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

accuracy_score (Y_test,pred)
# Out:
# 0.8666666666666667
